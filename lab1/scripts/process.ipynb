# %%
import matplotlib.pyplot as plt
import seaborn as sns

I1=[3.72,2.32,1.48,1.09,0.86]
U1=[5.58,5.79,5.92,5.98,6.02]

I2=[5.33,2.15,1.41,1.11,0.69]
U2=[5.33,5.82,5.93,5.98,6.04]

I3=[5.83,2.73,1.24,0.94,0.67]
U3=[5.25,5.73,5.96,6.00,6.04]

sns.set_style("whitegrid")

sns.scatterplot(x=I1, y=U1)
sns.lineplot(x=I1, y=U1,label='U-I')

sns.scatterplot(x=I2, y=U2, color='red')
sns.lineplot(x=I2, y=U2, color='red',label='U\'-I\'')

sns.scatterplot(x=I3, y=U3, color='green')
sns.lineplot(x=I3, y=U3, color='green',label='U\'\'-I\'\'')


plt.xlim(0,8)
plt.ylim(2,8)
plt.legend()
# Set the color of the axes to black
ax = plt.gca()
ax.spines['bottom'].set_color('black')
ax.spines['left'].set_color('black')

# Add arrows at the ends of the axis
plt.annotate('', xy=(8, 2), xytext=(0, 2), arrowprops=dict(arrowstyle='->', color='black'))
plt.annotate('', xy=(0, 8), xytext=(0, 2), arrowprops=dict(arrowstyle='->', color='black'))

# Add x labels
plt.text(8, 1.5, 'I(mA )', ha='right')
plt.text(8, 2.2, 'I\'(mA )', ha='right')
plt.text(8, 2.65, 'I\'\'(mA )', ha='right')

# Add y labels
plt.text(0.1, 7.9, 'U(V )', va='top')
plt.text(0.1, 7.5, 'U\'(V )', va='top')
plt.text(0.1, 7.1, 'U\'\'(V )', va='top')

plt.show()
# Out:
# c:\conda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\conda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\conda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\conda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
import numpy as np

I1=[3.72,2.32,1.48,1.09,0.86]
U1=[5.58,5.79,5.92,5.98,6.02]

I2=[5.33,2.15,1.41,1.11,0.69]
U2=[5.33,5.82,5.93,5.98,6.04]

I3=[5.83,2.73,1.24,0.94,0.67]
U3=[5.25,5.73,5.96,6.00,6.04]

# Fit the data to a line
coeffs1 = np.polyfit(I1, U1, 1)
coeffs2 = np.polyfit(I2, U2, 1)
coeffs3 = np.polyfit(I3, U3, 1)

# The slope and intercept of the fitted line are
slope1, intercept1 = coeffs1
slope2, intercept2 = coeffs2
slope3, intercept3 = coeffs3

print("For the first set of data, the slope is {:.4f} and the intercept is {:.4f}".format(slope1, intercept1))
print("For the second set of data, the slope is {:.4f} and the intercept is {:.4f}".format(slope2, intercept2))
print("For the third set of data, the slope is {:.4f} and the intercept is {:.4f}".format(slope3, intercept3))
# Out:
# For the first set of data, the slope is -0.1532 and the intercept is 6.1482
# For the second set of data, the slope is -0.1533 and the intercept is 6.1478
# For the third set of data, the slope is -0.1535 and the intercept is 6.1462
